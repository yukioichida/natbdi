# %%
import json

import lightning as L
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from datasets import Dataset, Features, Sequence, Value
from lightning import Trainer
from lightning.pytorch.callbacks import ModelCheckpoint
from lightning.pytorch.loggers import TensorBoardLogger
from scienceworld import ScienceWorldEnv
from torch.utils.data import DataLoader

from sources.fallback_policy.encoder import HFEncoderModel, EncoderModel
from sources.fallback_policy.model import BeliefBaseEncoder, ContrastiveQNetwork
from sources.scienceworld import parse_beliefs

# %%
encoder_model = HFEncoderModel("princeton-nlp/sup-simcse-roberta-base", device='cuda')
# Out:
# /home/ichida/miniconda3/envs/default_env/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
goldpath_df = pd.read_csv("/opt/data/scienceworld-goldpaths/trajectories_csv/tabular_task-1-boil.csv")
goldpath_df = goldpath_df[goldpath_df['variation_idx'] == 0]  # TODO: remover filtro
goldpath_df = goldpath_df.sort_values("turn")
goldpath_df
# Out:
#     turn                                        look_around  \
# 0      1  This room is called the hallway. In it, you se...
# 1      2  This room is called the hallway. In it, you se...
# 2      3  This room is called the kitchen. In it, you se...
# 3      4  This room is called the kitchen. In it, you se...
# 4      5  This room is called the kitchen. In it, you se...
# 5      6  This room is called the kitchen. In it, you se...
# 6      7  This room is called the kitchen. In it, you se...
# 7      8  This room is called the kitchen. In it, you se...
# 8      9  This room is called the kitchen. In it, you se...
# 9     10  This room is called the kitchen. In it, you se...
# 10    11  This room is called the kitchen. In it, you se...
# 11    12  This room is called the kitchen. In it, you se...
# 12    13  This room is called the kitchen. In it, you se...
# 13    14  This room is called the kitchen. In it, you se...
# 14    15  This room is called the kitchen. In it, you se...
# 15    16  This room is called the kitchen. In it, you se...
# 16    17  This room is called the kitchen. In it, you se...
# 17    18  This room is called the kitchen. In it, you se...
# 18    19  This room is called the kitchen. In it, you se...
# 19    20  This room is called the kitchen. In it, you se...
# 20    21  This room is called the kitchen. In it, you se...
# 21    22  This room is called the kitchen. In it, you se...
# 22    23  This room is called the kitchen. In it, you se...
# 23    24  This room is called the kitchen. In it, you se...
# 24    25  This room is called the kitchen. In it, you se...
# 25    26  This room is called the kitchen. In it, you se...
# 26    27  This room is called the kitchen. In it, you se...
# 27    28  This room is called the kitchen. In it, you se...
# 28    29  This room is called the kitchen. In it, you se...
# 29    30  This room is called the kitchen. In it, you se...
# 30    31  This room is called the kitchen. In it, you se...
# 31    32  This room is called the kitchen. In it, you se...
# 32    33  This room is called the kitchen. In it, you se...
# 33    34  This room is called the kitchen. In it, you se...
# 34    35  This room is called the kitchen. In it, you se...
# 35    36  This room is called the kitchen. In it, you se...
# 36    37  This room is called the kitchen. In it, you se...
#
#                                           observation  \
# 0                           The door is already open.
# 1                            You move to the kitchen.
# 2          You move the thermometer to the inventory.
# 3                           The cupboard is now open.
# 4            You move the metal pot to the inventory.
# 5                 You move the metal pot to the sink.
# 6                          The sink is now activated.
# 7                        The sink is now deactivated.
# 8            You move the metal pot to the inventory.
# 9                             You focus on the water.
# 10              You can't move something into itself.
# 11           You move the metal pot to the inventory.
# 12               You move the metal pot to the stove.
# 13                        The stove is now activated.
# 14                           a substance called water
# 15  the thermometer measures a temperature of 13 d...
# 16                           a substance called water
# 17  the thermometer measures a temperature of 20 d...
# 18                           a substance called water
# 19  the thermometer measures a temperature of 28 d...
# 20                           a substance called water
# 21  the thermometer measures a temperature of 38 d...
# 22                           a substance called water
# 23  the thermometer measures a temperature of 48 d...
# 24                           a substance called water
# 25  the thermometer measures a temperature of 58 d...
# 26                           a substance called water
# 27  the thermometer measures a temperature of 68 d...
# 28                           a substance called water
# 29  the thermometer measures a temperature of 78 d...
# 30                           a substance called water
# 31  the thermometer measures a temperature of 88 d...
# 32                           a substance called water
# 33  the thermometer measures a temperature of 98 d...
# 34                           a substance called steam
# 35  the thermometer measures a temperature of 107 ...
# 36               You decide to wait for 1 iterations.
#
#                                             inventory  \
# 0          In your inventory, you see:\n\tan orange\n
# 1          In your inventory, you see:\n\tan orange\n
# 2          In your inventory, you see:\n\tan orange\n
# 3   In your inventory, you see:\n\ta thermometer, ...
# 4   In your inventory, you see:\n\ta thermometer, ...
# 5   In your inventory, you see:\n\ta thermometer, ...
# 6   In your inventory, you see:\n\ta thermometer, ...
# 7   In your inventory, you see:\n\ta thermometer, ...
# 8   In your inventory, you see:\n\ta thermometer, ...
# 9   In your inventory, you see:\n\ta thermometer, ...
# 10  In your inventory, you see:\n\ta thermometer, ...
# 11  In your inventory, you see:\n\ta thermometer, ...
# 12  In your inventory, you see:\n\ta thermometer, ...
# 13  In your inventory, you see:\n\ta thermometer, ...
# 14  In your inventory, you see:\n\ta thermometer, ...
# 15  In your inventory, you see:\n\ta thermometer, ...
# 16  In your inventory, you see:\n\ta thermometer, ...
# 17  In your inventory, you see:\n\ta thermometer, ...
# 18  In your inventory, you see:\n\ta thermometer, ...
# 19  In your inventory, you see:\n\ta thermometer, ...
# 20  In your inventory, you see:\n\ta thermometer, ...
# 21  In your inventory, you see:\n\ta thermometer, ...
# 22  In your inventory, you see:\n\ta thermometer, ...
# 23  In your inventory, you see:\n\ta thermometer, ...
# 24  In your inventory, you see:\n\ta thermometer, ...
# 25  In your inventory, you see:\n\ta thermometer, ...
# 26  In your inventory, you see:\n\ta thermometer, ...
# 27  In your inventory, you see:\n\ta thermometer, ...
# 28  In your inventory, you see:\n\ta thermometer, ...
# 29  In your inventory, you see:\n\ta thermometer, ...
# 30  In your inventory, you see:\n\ta thermometer, ...
# 31  In your inventory, you see:\n\ta thermometer, ...
# 32  In your inventory, you see:\n\ta thermometer, ...
# 33  In your inventory, you see:\n\ta thermometer, ...
# 34  In your inventory, you see:\n\ta thermometer, ...
# 35  In your inventory, you see:\n\ta thermometer, ...
# 36  In your inventory, you see:\n\ta thermometer, ...
#
#                                                action     score   done  \
# 0                                open door to kitchen  0.000000  False
# 1                                       go to kitchen  0.000000  False
# 2                                 pick up thermometer  0.000000  False
# 3                                       open cupboard  0.000000  False
# 4                                   pick up metal pot  0.000000  False
# 5                              move metal pot to sink  0.000000  False
# 6                                       activate sink  0.033333  False
# 7                                     deactivate sink  0.033333  False
# 8                                   pick up metal pot  0.033333  False
# 9                     focus on substance in metal pot  0.700000  False
# 10                      pour metal pot into metal pot  0.700000  False
# 11                                  pick up metal pot  0.700000  False
# 12                            move metal pot to stove  0.716667  False
# 13                                     activate stove  0.733333  False
# 14                     examine substance in metal pot  0.733333  False
# 15  use thermometer in inventory on substance in m...  0.733333  False
# 16                     examine substance in metal pot  0.733333  False
# 17  use thermometer in inventory on substance in m...  0.733333  False
# 18                     examine substance in metal pot  0.733333  False
# 19  use thermometer in inventory on substance in m...  0.750000  False
# 20                     examine substance in metal pot  0.750000  False
# 21  use thermometer in inventory on substance in m...  0.750000  False
# 22                     examine substance in metal pot  0.750000  False
# 23  use thermometer in inventory on substance in m...  0.750000  False
# 24                     examine substance in metal pot  0.750000  False
# 25  use thermometer in inventory on substance in m...  0.750000  False
# 26                     examine substance in metal pot  0.750000  False
# 27  use thermometer in inventory on substance in m...  0.750000  False
# 28                     examine substance in metal pot  0.750000  False
# 29  use thermometer in inventory on substance in m...  0.750000  False
# 30                     examine substance in metal pot  0.750000  False
# 31  use thermometer in inventory on substance in m...  0.750000  False
# 32                     examine substance in metal pot  0.750000  False
# 33  use thermometer in inventory on substance in m...  1.000000   True
# 34                                      examine steam  1.000000   True
# 35              use thermometer in inventory on steam  1.000000   True
# 36                                              wait1  1.000000   True
#
#                           goal  \
# 0   Your task is to boil water
# 1   Your task is to boil water
# 2   Your task is to boil water
# 3   Your task is to boil water
# 4   Your task is to boil water
# 5   Your task is to boil water
# 6   Your task is to boil water
# 7   Your task is to boil water
# 8   Your task is to boil water
# 9   Your task is to boil water
# 10  Your task is to boil water
# 11  Your task is to boil water
# 12  Your task is to boil water
# 13  Your task is to boil water
# 14  Your task is to boil water
# 15  Your task is to boil water
# 16  Your task is to boil water
# 17  Your task is to boil water
# 18  Your task is to boil water
# 19  Your task is to boil water
# 20  Your task is to boil water
# 21  Your task is to boil water
# 22  Your task is to boil water
# 23  Your task is to boil water
# 24  Your task is to boil water
# 25  Your task is to boil water
# 26  Your task is to boil water
# 27  Your task is to boil water
# 28  Your task is to boil water
# 29  Your task is to boil water
# 30  Your task is to boil water
# 31  Your task is to boil water
# 32  Your task is to boil water
# 33  Your task is to boil water
# 34  Your task is to boil water
# 35  Your task is to boil water
# 36  Your task is to boil water
#
#                                      task_description   fold  variation_idx  \
# 0   Your task is to boil water. For compounds with...  train              0
# 1   Your task is to boil water. For compounds with...  train              0
# 2   Your task is to boil water. For compounds with...  train              0
# 3   Your task is to boil water. For compounds with...  train              0
# 4   Your task is to boil water. For compounds with...  train              0
# 5   Your task is to boil water. For compounds with...  train              0
# 6   Your task is to boil water. For compounds with...  train              0
# 7   Your task is to boil water. For compounds with...  train              0
# 8   Your task is to boil water. For compounds with...  train              0
# 9   Your task is to boil water. For compounds with...  train              0
# 10  Your task is to boil water. For compounds with...  train              0
# 11  Your task is to boil water. For compounds with...  train              0
# 12  Your task is to boil water. For compounds with...  train              0
# 13  Your task is to boil water. For compounds with...  train              0
# 14  Your task is to boil water. For compounds with...  train              0
# 15  Your task is to boil water. For compounds with...  train              0
# 16  Your task is to boil water. For compounds with...  train              0
# 17  Your task is to boil water. For compounds with...  train              0
# 18  Your task is to boil water. For compounds with...  train              0
# 19  Your task is to boil water. For compounds with...  train              0
# 20  Your task is to boil water. For compounds with...  train              0
# 21  Your task is to boil water. For compounds with...  train              0
# 22  Your task is to boil water. For compounds with...  train              0
# 23  Your task is to boil water. For compounds with...  train              0
# 24  Your task is to boil water. For compounds with...  train              0
# 25  Your task is to boil water. For compounds with...  train              0
# 26  Your task is to boil water. For compounds with...  train              0
# 27  Your task is to boil water. For compounds with...  train              0
# 28  Your task is to boil water. For compounds with...  train              0
# 29  Your task is to boil water. For compounds with...  train              0
# 30  Your task is to boil water. For compounds with...  train              0
# 31  Your task is to boil water. For compounds with...  train              0
# 32  Your task is to boil water. For compounds with...  train              0
# 33  Your task is to boil water. For compounds with...  train              0
# 34  Your task is to boil water. For compounds with...  train              0
# 35  Your task is to boil water. For compounds with...  train              0
# 36  Your task is to boil water. For compounds with...  train              0
#
#       task_name  task_idx
# 0   task-1-boil         0
# 1   task-1-boil         0
# 2   task-1-boil         0
# 3   task-1-boil         0
# 4   task-1-boil         0
# 5   task-1-boil         0
# 6   task-1-boil         0
# 7   task-1-boil         0
# 8   task-1-boil         0
# 9   task-1-boil         0
# 10  task-1-boil         0
# 11  task-1-boil         0
# 12  task-1-boil         0
# 13  task-1-boil         0
# 14  task-1-boil         0
# 15  task-1-boil         0
# 16  task-1-boil         0
# 17  task-1-boil         0
# 18  task-1-boil         0
# 19  task-1-boil         0
# 20  task-1-boil         0
# 21  task-1-boil         0
# 22  task-1-boil         0
# 23  task-1-boil         0
# 24  task-1-boil         0
# 25  task-1-boil         0
# 26  task-1-boil         0
# 27  task-1-boil         0
# 28  task-1-boil         0
# 29  task-1-boil         0
# 30  task-1-boil         0
# 31  task-1-boil         0
# 32  task-1-boil         0
# 33  task-1-boil         0
# 34  task-1-boil         0
# 35  task-1-boil         0
# 36  task-1-boil         0

# %% [markdown]
# # Loading Trajectories

# %%
all_trajectories = []

previous_actions = []
observation = ""
for i, row in goldpath_df.iterrows():
    belief_base = parse_beliefs(observation=observation, look=row['look_around'], inventory=row['inventory'])
    belief_base = [b for b in belief_base if len(b) > 0] + [row['goal']]
    for a in previous_actions[-5:]:
        belief_base.append(f"You executed the action {a['action']} at turn {a['turn']}")

    belief_base_sizes = len(belief_base) + 1
    action = row['action']
    all_trajectories.append({
            'belief_base': belief_base,
            'action': action,
            'belief_base_sizes': belief_base_sizes,
    })
    
    previous_actions.append({
                    'turn': row['turn'],
                    'action': action
            })
    
    observation = row['observation']


trajectories_pd = pd.DataFrame(all_trajectories)
dataset = Dataset.from_pandas(trajectories_pd, features=Features({
        "belief_base": Sequence(Value(dtype="string")),
        "action": Value(dtype="string"),
        "belief_base_sizes": Value(dtype="int32")
}))

# %%
def collate_fn(data):
    # tem que fazer o encode aqui, para entregar batchs de vetores prontos
    actions = [d['action'] for d in data]
    belief_base_sizes = [d['belief_base_sizes'] for d in data]
    belief_base = [d['belief_base'] for d in data]

    return {'actions': actions,
            'belief_base_sizes': belief_base_sizes,
            'belief_base': belief_base}
dataloader = DataLoader(dataset, collate_fn=collate_fn, batch_size=8, shuffle=True)

# %%
EPOCHS = 40
model = ContrastiveQNetwork(768, encoder_model=encoder_model)

base_dir = "cl_step"
tb_logger = TensorBoardLogger(f"logs/{base_dir}")
tb_logger.log_hyperparams(model.hparams)
version = tb_logger.version
filename = base_dir + "/version_" + str(version) + "/" + "v" + str(
        version) + "-{epoch}-{step}-{train_loss_epoch:.3f}"
checkpoint_callback = ModelCheckpoint(dirpath='checkpoints',
                                      monitor='train_loss_epoch',
                                      save_top_k=2,
                                      filename=filename)

trainer = Trainer(max_epochs=EPOCHS,
                  accelerator='gpu',
                  logger=tb_logger,
                  callbacks=[checkpoint_callback]
                  )
trainer.fit(model, dataloader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 3060') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                | Type              | Params
# ----------------------------------------------------------
# 0 | belief_base_encoder | BeliefBaseEncoder | 5.9 M
# 1 | similarity_function | CosineSimilarity  | 0
# 2 | linear_act          | Linear            | 590 K
# 3 | linear_belief       | Linear            | 590 K
# ----------------------------------------------------------
# 7.1 M     Trainable params
# 0         Non-trainable params
# 7.1 M     Total params
# 28.330    Total estimated model params size (MB)
# /home/ichida/miniconda3/envs/default_env/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# /home/ichida/miniconda3/envs/default_env/lib/python3.11/site-packages/lightning/pytorch/loops/fit_loop.py:298: The number of training batches (5) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=40` reached.

# %%
model = model.to('cuda')
model = model.eval()

env = ScienceWorldEnv()
goal = row['goal']
variation_idx = row['variation_idx']

env.load("boil", variation_idx, "openDoors")
with torch.no_grad():
    max_steps = 30
    action = "look around"

    plan = []
    previous_action = []
    for step in range(max_steps):
        obs, reward, is_done, info = env.step(action)

        print(f" => Step {step} - reward: {reward:.3f} - is_done: {is_done} - action: {action}")
        belief_base = parse_beliefs(observation=obs, look=info['look'], inventory=info['inv']) + [goal]
        belief_base = [b.replace("greenhouse", "green house") for b in belief_base]

        for a in previous_action[-5:]:
            belief_base.append(f"You executed the action {a['action']} at turn {a['turn']}")

        num_beliefs = len(belief_base) + 1 + 1  # including cls
        # candidate_actions = available_actions
        candidate_actions = info['valid']
        # q_values = model.act(belief_base, candidate_actions=info['valid'])
        q_values = model.act(belief_base, candidate_actions=candidate_actions)
        selected_action = q_values.argmax(dim=-1)[0]
        action = candidate_actions[selected_action]
        # if i == 1:
        #   action = "focus on substance in metal pot"
        # print(f"Belief Base: {belief_base}")
        #print(f"obs: {obs}")
        #print(f"Selected action: {action}")
        values, idxs = torch.sort(q_values.squeeze(0), descending=True)

        top_k = 3
        #print(f"\tAction space - Top {top_k}:")
        #for i, idx in enumerate(idxs[:top_k]):
        #    print(f"\t\tCandidate Action: {candidate_actions[idx]} - q_value: {values[i]:.3f}")

        plan.append(action)

        previous_action.append({
                'turn': step,
                'action': action
        })

    #print("Plan Executed: ")
    #for i, a in enumerate(plan):
    #    print(f"{i} -  {a}")
# Out:
#  => Step 0 - reward: 0.000 - is_done: False - action: look around
#  => Step 1 - reward: 0.000 - is_done: False - action: go to kitchen
#  => Step 2 - reward: 0.000 - is_done: False - action: pick up thermometer
#  => Step 3 - reward: 0.000 - is_done: False - action: open cupboard
#  => Step 4 - reward: 0.000 - is_done: False - action: pick up metal pot
#  => Step 5 - reward: 0.000 - is_done: False - action: move metal pot to sink
#  => Step 6 - reward: 3.000 - is_done: False - action: activate sink
#  => Step 7 - reward: 0.000 - is_done: False - action: deactivate sink
#  => Step 8 - reward: 0.000 - is_done: False - action: pick up metal pot
#  => Step 9 - reward: 67.000 - is_done: False - action: focus on substance in metal pot
#  => Step 10 - reward: 0.000 - is_done: False - action: pour metal pot into metal pot
#  => Step 11 - reward: 0.000 - is_done: False - action: focus on metal pot
#  => Step 12 - reward: 0.000 - is_done: False - action: move metal pot to stove
#  => Step 13 - reward: 3.000 - is_done: False - action: activate stove
#  => Step 14 - reward: 0.000 - is_done: False - action: connect stove to air
#  => Step 15 - reward: 0.000 - is_done: False - action: connect stove to air
#  => Step 16 - reward: 0.000 - is_done: False - action: look at substance in metal pot
#  => Step 17 - reward: 0.000 - is_done: False - action: use thermometer on inventory
#  => Step 18 - reward: 0.000 - is_done: False - action: look at substance in metal pot
#  => Step 19 - reward: 0.000 - is_done: False - action: use thermometer on inventory
#  => Step 20 - reward: 0.000 - is_done: False - action: look at substance in metal pot
#  => Step 21 - reward: 0.000 - is_done: False - action: use thermometer on inventory
#  => Step 22 - reward: 0.000 - is_done: False - action: look at substance in metal pot
#  => Step 23 - reward: 0.000 - is_done: False - action: use thermometer on inventory
#  => Step 24 - reward: 0.000 - is_done: False - action: look at substance in metal pot
#  => Step 25 - reward: 0.000 - is_done: False - action: use thermometer on substance in metal pot
#  => Step 26 - reward: 0.000 - is_done: False - action: look at substance in metal pot
#  => Step 27 - reward: 0.000 - is_done: False - action: use thermometer on inventory
#  => Step 28 - reward: 0.000 - is_done: False - action: look at substance in metal pot
#  => Step 29 - reward: 0.000 - is_done: False - action: use thermometer on inventory
